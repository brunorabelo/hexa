# %%
import csv
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from datetime import datetime
from sklearn.model_selection import train_test_split

# %%
train_data = pd.read_csv("data/train_with_embeddings_pca.csv")

# %%
# new features
train_data["url_count"] = train_data["urls"].apply(lambda s: s[1:-1].count("\'")/2)
train_data["text_len"] = train_data["text"].apply(lambda s: len(s))
train_data["hashtags_count"] = train_data["hashtags"].apply(lambda s: s[1:-1].count("\'")/2)
train_data["day"] = train_data["timestamp"].apply(lambda t: datetime.utcfromtimestamp(t/1000).day)
train_data["hour"] = train_data["timestamp"].apply(lambda t: datetime.utcfromtimestamp(t/1000).hour)

# indicators of keywords
train_data["Macron"] =  train_data["text"].apply(lambda s: ("macron" in s.lower().split()))
train_data["Zemmour"] =  train_data["text"].apply(lambda s: ("zemmour" in s.lower().split()))
train_data["Melenchon"] =  train_data["text"].apply(lambda s: ("melenchon" in s.replace("é","e").lower().split()))
train_data["rt"] =  train_data["text"].apply(lambda s: ("rt" in s.lower().split()))

# %%
display(train_data)
# Out:
#         Unnamed: 0                                               text  \
# 0                0                 rt refarcir macron ans nom prépare
# 1                1                                          populaire
# 2                2                                faut dégager cinglé
# 3                3  enseignants mettre prescriptions président rép...
# 4                4                         mafieuse oppressive macron
# ...            ...                                                ...
# 353964      353964                     gonflette tour raciste frustré
# 353965      353965  france caste crapuleuse encadrée gangsters irr...
# 353966      353966                      eric zemmour français berbère
# 353967      353967                           gauchistes dépression pq
# 353968      353968      algérie emmanuel macron grande histoire amour
#
#         retweets_count  favorites_count  followers_count  statuses_count  \
# 0                    3                0             3682          453535
# 1                    0                0               86            1016
# 2                    3                1             1944           28234
# 3                    0                0                1            1072
# 4                    0                0            13957           25311
# ...                ...              ...              ...             ...
# 353964               0                0               34            1509
# 353965               0                0               89           11166
# 353966               3                0             1888             712
# 353967               0                0              139             486
# 353968               0                0                0              82
#
#         friends_count mentions                         urls  verified  ...  \
# 0                3628       []                           []         0  ...
# 1                 284       []                           []         0  ...
# 2                1995       []                           []         0  ...
# 3                   0       []  ['https://t.co/rytlted08g']         0  ...
# 4               10841       []                           []         0  ...
# ...               ...      ...                          ...       ...  ...
# 353964             55       []  ['https://t.co/pma33zhslx']         0  ...
# 353965            127       []                           []         0  ...
# 353966           3086       []                           []         0  ...
# 353967            320       []                           []         0  ...
# 353968             24       []                           []         0  ...
#
#                 7  url_count  text_len  hashtags_count  day  hour  Macron  \
# 0        0.606284        0.0        34             0.0   11     5    True
# 1       -1.313150        0.0         9             0.0   19    12   False
# 2       -1.363875        0.0        19             0.0   15    18   False
# 3      -15.030526        1.0       123             0.0   14    11   False
# 4       -1.137621        0.0        26             0.0   14    11    True
# ...           ...        ...       ...             ...  ...   ...     ...
# 353964   3.542597        1.0        30             0.0   16    13   False
# 353965  -2.476907        0.0        69             0.0   12     8   False
# 353966   5.176164        0.0        29             0.0   18    12   False
# 353967  -0.109183        0.0        24             0.0   11     8   False
# 353968   3.258473        0.0        45             0.0   18    11    True
#
#         Zemmour  Melenchon     rt
# 0         False      False   True
# 1         False      False  False
# 2         False      False  False
# 3         False      False  False
# 4         False      False  False
# ...         ...        ...    ...
# 353964    False      False  False
# 353965    False      False  False
# 353966     True      False  False
# 353967    False      False  False
# 353968    False      False  False
#
# [353969 rows x 30 columns]

# %%
# select useful columns
train_data_filtered = train_data.drop(["text", "urls", "mentions", "hashtags", "timestamp", "TweetID"], axis=1)
# train_data_filtered = train_data.loc[:, ["retweets_count","favorites_count","followers_count","statuses_count","friends_count",
#                                  "hashtags_count","hour","verified","url_count","text_len","rt","Macron","Zemmour","Melenchon"]]


X_train, X_eval, y_train, y_eval = train_test_split(train_data_filtered.drop("retweets_count", axis=1),
                                                    train_data_filtered["retweets_count"],
                                                    random_state=42, test_size=0.1)

# Standardize the data
normal_columns = train_data_filtered.drop(["hour", "verified", "Macron", "Zemmour", "Melenchon", "url_count", "rt", "retweets_count"], axis=1).columns
mu, sigma = X_train[normal_columns].mean(axis=0), X_train[normal_columns].std(axis=0)
X_train.loc[:, normal_columns] = (X_train[normal_columns] - mu) / sigma
X_eval.loc[:, normal_columns] = (X_eval[normal_columns] - mu) / sigma

# %%
# import os
# os.environ['CUDA_VISIBLE_DEVICES'] = "0"

# %%
import tensorflow as tf

# %%
from tensorflow.python.client import device_lib 
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 13706083938008076513
# xla_global_id: -1
# ]

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(1),
])

# %%
# import tensorflow_addons as tfa
# optimizer = tfa.optimizers.AdamW(learning_rate=1e-3, weight_decay=1e-4)
# model.compile(optimizer=optimizer, loss='mae')

# %%
model.compile(optimizer="adam", loss='mae')

# %%
history = model.fit(X_train.values.astype(np.float32), y_train.values.astype(np.float32), epochs=37, batch_size=256,
         validation_data=(X_eval.values.astype(np.float32), y_eval.values.astype(np.float32)), shuffle=True)
# Out:
# Epoch 1/37
# 1245/1245 [==============================] - 4s 3ms/step - loss: 6.2997 - val_loss: 6.1442
# Epoch 2/37
# 1245/1245 [==============================] - 4s 3ms/step - loss: 6.3325 - val_loss: 6.3132
# Epoch 3/37
# 1245/1245 [==============================] - 3s 3ms/step - loss: 6.2496 - val_loss: 5.9331
# Epoch 4/37
# 1245/1245 [==============================] - 3s 2ms/step - loss: 6.2362 - val_loss: 5.9771
# Epoch 5/37
# 1245/1245 [==============================] - 3s 3ms/step - loss: 6.1976 - val_loss: 6.0643
# Epoch 6/37
# 1245/1245 [==============================] - 4s 3ms/step - loss: 6.3246 - val_loss: 5.9675
# Epoch 7/37
# 1245/1245 [==============================] - 3s 3ms/step - loss: 6.2017 - val_loss: 5.9469
# Epoch 8/37
# 1245/1245 [==============================] - 3s 2ms/step - loss: 6.2719 - val_loss: 5.9588
# Epoch 9/37
# 1245/1245 [==============================] - 3s 3ms/step - loss: 6.2117 - val_loss: 6.0205
# Epoch 10/37
# 1245/1245 [==============================] - 3s 3ms/step - loss: 6.2123 - val_loss: 6.4195
# Epoch 11/37
# 1245/1245 [==============================] - 4s 3ms/step - loss: 6.2564 - val_loss: 6.0441
# Epoch 12/37
# 1245/1245 [==============================] - 4s 3ms/step - loss: 6.1545 - val_loss: 6.0260
# Epoch 13/37
# 1245/1245 [==============================] - 3s 3ms/step - loss: 6.2439 - val_loss: 6.0812
# Epoch 14/37
# 1245/1245 [==============================] - 3s 3ms/step - loss: 6.1386 - val_loss: 6.0417
# Epoch 15/37
# 1245/1245 [==============================] - 3s 3ms/step - loss: 6.1524 - val_loss: 6.0909
# Epoch 16/37
# 1245/1245 [==============================] - 4s 3ms/step - loss: 6.1444 - val_loss: 6.0655
# Epoch 17/37
# 1245/1245 [==============================] - 4s 3ms/step - loss: 6.1447 - val_loss: 6.0148
# Epoch 18/37
# 1245/1245 [==============================] - 4s 3ms/step - loss: 6.2025 - val_loss: 6.0647
# Epoch 19/37
# 1245/1245 [==============================] - 4s 3ms/step - loss: 6.1490 - val_loss: 6.0262
# Epoch 20/37
# 1245/1245 [==============================] - 4s 3ms/step - loss: 6.1193 - val_loss: 6.0427
# Epoch 21/37
# 1245/1245 [==============================] - 4s 3ms/step - loss: 6.1466 - val_loss: 6.2350
# Epoch 22/37
# 1245/1245 [==============================] - 4s 3ms/step - loss: 6.0326 - val_loss: 6.0409
# Epoch 23/37
# 1245/1245 [==============================] - 4s 3ms/step - loss: 6.0761 - val_loss: 6.0537
# Epoch 24/37
# 1245/1245 [==============================] - 4s 3ms/step - loss: 6.1263 - val_loss: 6.0137
# Epoch 25/37
# 1245/1245 [==============================] - 4s 3ms/step - loss: 6.0968 - val_loss: 6.2127
# Epoch 26/37
# 1245/1245 [==============================] - 4s 3ms/step - loss: 6.0571 - val_loss: 6.1785
# Epoch 27/37
# 1245/1245 [==============================] - 4s 3ms/step - loss: 6.0409 - val_loss: 6.1396
# Epoch 28/37
# 1245/1245 [==============================] - 4s 3ms/step - loss: 6.1435 - val_loss: 5.9569
# Epoch 29/37
# 1245/1245 [==============================] - 4s 3ms/step - loss: 6.0846 - val_loss: 6.0866
# Epoch 30/37
# 1245/1245 [==============================] - 4s 3ms/step - loss: 5.9806 - val_loss: 6.0131
# Epoch 31/37
# 1245/1245 [==============================] - 4s 3ms/step - loss: 6.1059 - val_loss: 6.0166
# Epoch 32/37
# 1245/1245 [==============================] - 4s 3ms/step - loss: 6.0594 - val_loss: 5.9852
# Epoch 33/37
# 1245/1245 [==============================] - 4s 3ms/step - loss: 6.1259 - val_loss: 6.2035
# Epoch 34/37
# 1245/1245 [==============================] - 4s 3ms/step - loss: 6.0287 - val_loss: 6.1775
# Epoch 35/37
# 1245/1245 [==============================] - 4s 3ms/step - loss: 6.0568 - val_loss: 6.0460
# Epoch 36/37
# 1245/1245 [==============================] - 4s 3ms/step - loss: 6.0287 - val_loss: 6.1803
# Epoch 37/37
# 1245/1245 [==============================] - 4s 3ms/step - loss: 6.0268 - val_loss: 6.0869

# %%
plt.plot(history.epoch, history.history["loss"], 'b', label='Training loss')
plt.plot(history.epoch, history.history["val_loss"], 'g', label='Validation loss')
plt.title('Training loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
model.evaluate(X_eval.values.astype(np.float32),  y_eval.values.astype(np.float32), verbose=2)
# Out:
# 1107/1107 - 0s - loss: 5.9674 - 484ms/epoch - 437us/step
# 5.967412948608398

# %%
pred = model.predict(X_train.values.astype(np.float32))
print(pred)
# Out:
# 9956/9956 [==============================] - 6s 632us/step
# [[2.1647137e-04]
#  [9.2162377e-01]
#  [2.1647137e-04]
#  ...
#  [1.0225828e+00]
#  [2.1647137e-04]
#  [1.0228519e+00]]

# %%
# plt.scatter(X_train["favorites_count"], model.predict(X_train))
# plt.scatter(X_train["favorites_count"], y_train.values.astype(np.float32))

# %%
# evaluation

eval_data = pd.read_csv("data/evaluation_with_embeddings_pca.csv")
tweets = eval_data["TweetID"]

# %%
eval_data["url_count"] = eval_data["urls"].apply(lambda s: s[1:-1].count("\'")/2)
eval_data["text_len"] = eval_data["text"].apply(lambda s: len(s))
eval_data["hashtags_count"] = eval_data["hashtags"].apply(lambda s: s[1:-1].count("\'")/2)
eval_data["day"] = eval_data["timestamp"].apply(lambda t: datetime.utcfromtimestamp(t/1000).day)
eval_data["hour"] = eval_data["timestamp"].apply(lambda t: datetime.utcfromtimestamp(t/1000).hour)
eval_data["Macron"] =  eval_data["text"].apply(lambda s: ("macron" in s.lower().split()))
eval_data["Zemmour"] =  eval_data["text"].apply(lambda s: ("zemmour" in s.lower().split()))
eval_data["Melenchon"] =  eval_data["text"].apply(lambda s: ("melenchon" in s.lower().split()))
eval_data["rt"] =  eval_data["text"].apply(lambda s: ("rt" in s.lower().split()))

# print("sentiment analysis...")
# eval_data["compound"] =  eval_data["text"].apply(lambda s: sia.polarity_scores(s)['compound'])

eval_data = eval_data.drop(["text", "urls", "mentions", "hashtags", "timestamp", "TweetID"], axis=1)

# normalize
eval_data.loc[:, normal_columns] = (eval_data.loc[:, normal_columns] - mu) / sigma

print(eval_data)

pred = model.predict(eval_data.values.astype(np.float32))

print(pred)

# output normalization
for i,p in enumerate(pred):
    if p<0: pred[i] = 0
# Out:
#         Unnamed: 0  favorites_count  followers_count  statuses_count  \
# 0        -1.731691        -0.055089        -0.077561       -0.384487
# 1        -1.731681        -0.055089        -0.076250       -0.130940
# 2        -1.731672        -0.047990        -0.073569       -0.308274
# 3        -1.731662        -0.052722        -0.071378       -0.197070
# 4        -1.731652        -0.055089        -0.076932       -0.241396
# ...            ...              ...              ...             ...
# 117985   -0.577125        -0.055089        -0.077871       -0.421834
# 117986   -0.577115        -0.055089        -0.075036       -0.076371
# 117987   -0.577105        -0.040891        -0.074347       -0.403582
# 117988   -0.577095        -0.055089        -0.077867       -0.423504
# 117989   -0.577086        -0.055089        -0.075760       -0.373401
#
#         friends_count  verified         0         1         2         3  ...  \
# 0           -0.451430         0 -1.268766  0.106268  0.692711 -0.501750  ...
# 1           -0.405207         0 -1.269210 -0.576846 -0.046055  0.030241  ...
# 2            0.054226         0 -0.792288 -0.066508  0.465296 -0.202041  ...
# 3            0.229552         0  1.632202  2.311213  0.954841 -0.750197  ...
# 4           -0.434694         0  1.046772  0.416714  0.412183  2.431333  ...
# ...               ...       ...       ...       ...       ...       ...  ...
# 117985      -0.556227         0 -0.933475  0.074791  0.791673 -0.166126  ...
# 117986      -0.225498         0  0.365046 -0.424339  0.090706 -0.231096  ...
# 117987      -0.518372         0  0.326705 -0.559658  1.118146  1.182574  ...
# 117988      -0.549851         0  1.218310 -1.148457 -0.367896 -0.406155  ...
# 117989      -0.522357         0 -0.070005 -1.990002 -1.295944 -1.562515  ...
#
#                7  url_count  text_len  hashtags_count       day  hour  Macron  \
# 0       0.161070        0.0 -1.057548        2.208030  1.083457    12   False
# 1       0.251868        0.0 -0.913399       -0.384757  1.083457    11   False
# 2       0.076387        0.0 -0.673151        0.911637 -1.332955     8   False
# 3       2.055479        1.0  1.152732       -0.384757 -0.426800     8    True
# 4       0.806154        2.0  1.489079       -0.384757  1.385508    21   False
# ...          ...        ...       ...             ...       ...   ...     ...
# 117985  0.044995        0.0 -1.009498       -0.384757 -0.728852    16   False
# 117986 -1.055778        1.0  1.801401       -0.384757  0.781405     4   False
# 117987 -0.247690        0.0 -0.048507       -0.384757  0.781405    13    True
# 117988 -1.498543        1.0  1.585178       -0.384757  1.083457    12   False
# 117989 -0.649885        0.0 -0.120581       -0.384757 -0.124749    13   False
#
#         Zemmour  Melenchon     rt
# 0         False      False  False
# 1         False      False  False
# 2         False      False  False
# 3         False      False  False
# 4          True      False  False
# ...         ...        ...    ...
# 117985    False      False  False
# 117986    False      False  False
# 117987    False      False  False
# 117988    False      False  False
# 117989    False      False   True
#
# [117990 rows x 23 columns]
# 3688/3688 [==============================] - 3s 853us/step
# [[2.1647137e-04]
#  [2.1647137e-04]
#  [2.1293364e+00]
#  ...
#  [2.8285146e+00]
#  [2.1647137e-04]
#  [2.1647137e-04]]

# %%
with open("data/predictions.csv", 'w') as f:
    writer = csv.writer(f)
    writer.writerow(["TweetID", "retweets_count"])
    for index, prediction in enumerate(pred):
        writer.writerow([str(tweets[index]) , str(int(prediction))])
