# %%
import csv
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from datetime import datetime
from sklearn.model_selection import train_test_split

# %%
train_data = pd.read_csv("data/train_with_embeddings.csv")

# %%
# new features
train_data["url_count"] = train_data["urls"].apply(lambda s: s[1:-1].count("\'")/2)
train_data["text_len"] = train_data["text"].apply(lambda s: len(s))
train_data["hashtags_count"] = train_data["hashtags"].apply(lambda s: s[1:-1].count("\'")/2)
train_data["day"] = train_data["timestamp"].apply(lambda t: datetime.utcfromtimestamp(t/1000).day)
train_data["hour"] = train_data["timestamp"].apply(lambda t: datetime.utcfromtimestamp(t/1000).hour)

# indicators of keywords
train_data["Macron"] =  train_data["text"].apply(lambda s: ("macron" in s.lower().split()))
train_data["Zemmour"] =  train_data["text"].apply(lambda s: ("zemmour" in s.lower().split()))
train_data["Melenchon"] =  train_data["text"].apply(lambda s: ("melenchon" in s.replace("é","e").lower().split()))
train_data["rt"] =  train_data["text"].apply(lambda s: ("rt" in s.lower().split()))

# %%
display(train_data)
# Out:
#         Unnamed: 0                                               text  \
# 0                0                 rt refarcir macron ans nom prépare
# 1                1                                          populaire
# 2                2                                faut dégager cinglé
# 3                3  enseignants mettre prescriptions président rép...
# 4                4                         mafieuse oppressive macron
# ...            ...                                                ...
# 353964      353964                     gonflette tour raciste frustré
# 353965      353965  france caste crapuleuse encadrée gangsters irr...
# 353966      353966                      eric zemmour français berbère
# 353967      353967                           gauchistes dépression pq
# 353968      353968      algérie emmanuel macron grande histoire amour
#
#         retweets_count  favorites_count  followers_count  statuses_count  \
# 0                    3                0             3682          453535
# 1                    0                0               86            1016
# 2                    3                1             1944           28234
# 3                    0                0                1            1072
# 4                    0                0            13957           25311
# ...                ...              ...              ...             ...
# 353964               0                0               34            1509
# 353965               0                0               89           11166
# 353966               3                0             1888             712
# 353967               0                0              139             486
# 353968               0                0                0              82
#
#         friends_count mentions                         urls  verified  ...  \
# 0                3628       []                           []         0  ...
# 1                 284       []                           []         0  ...
# 2                1995       []                           []         0  ...
# 3                   0       []  ['https://t.co/rytlted08g']         0  ...
# 4               10841       []                           []         0  ...
# ...               ...      ...                          ...       ...  ...
# 353964             55       []  ['https://t.co/pma33zhslx']         0  ...
# 353965            127       []                           []         0  ...
# 353966           3086       []                           []         0  ...
# 353967            320       []                           []         0  ...
# 353968             24       []                           []         0  ...
#
#                15  url_count  text_len  hashtags_count  day  hour  Macron  \
# 0      -12.226419        0.0        34             0.0   11     5    True
# 1        4.243010        0.0         9             0.0   19    12   False
# 2       -6.869899        0.0        19             0.0   15    18   False
# 3      -21.181530        1.0       123             0.0   14    11   False
# 4       -4.781973        0.0        26             0.0   14    11    True
# ...           ...        ...       ...             ...  ...   ...     ...
# 353964   4.508761        1.0        30             0.0   16    13   False
# 353965  -3.818838        0.0        69             0.0   12     8   False
# 353966   1.522889        0.0        29             0.0   18    12   False
# 353967   2.717416        0.0        24             0.0   11     8   False
# 353968  -7.022976        0.0        45             0.0   18    11    True
#
#         Zemmour  Melenchon     rt
# 0         False      False   True
# 1         False      False  False
# 2         False      False  False
# 3         False      False  False
# 4         False      False  False
# ...         ...        ...    ...
# 353964    False      False  False
# 353965    False      False  False
# 353966     True      False  False
# 353967    False      False  False
# 353968    False      False  False
#
# [353969 rows x 38 columns]

# %%
# select useful columns
train_data_filtered = train_data.drop(["text", "urls", "mentions", "hashtags", "timestamp", "TweetID"], axis=1)
# train_data_filtered = train_data.loc[:, ["retweets_count","favorites_count","followers_count","statuses_count","friends_count",
#                                  "hashtags_count","hour","verified","url_count","text_len","rt","Macron","Zemmour","Melenchon"]]


X_train, X_eval, y_train, y_eval = train_test_split(train_data_filtered.drop("retweets_count", axis=1),
                                                    train_data_filtered["retweets_count"],
                                                    random_state=42, test_size=0.1)

# Standardize the data
normal_columns = train_data_filtered.drop(["hour", "verified", "Macron", "Zemmour", "Melenchon", "url_count", "rt", "retweets_count"], axis=1).columns
mu, sigma = X_train[normal_columns].mean(axis=0), X_train[normal_columns].std(axis=0)
X_train.loc[:, normal_columns] = (X_train[normal_columns] - mu) / sigma
X_eval.loc[:, normal_columns] = (X_eval[normal_columns] - mu) / sigma

# %%
import tensorflow as tf

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Dense(20, activation='relu'),
  tf.keras.layers.Dense(20, activation='relu'),
  tf.keras.layers.Dense(20, activation='relu'),
  tf.keras.layers.Dense(1),
])

# %%
# import tensorflow_addons as tfa
# optimizer = tfa.optimizers.AdamW(learning_rate=1e-3, weight_decay=1e-4)
# model.compile(optimizer=optimizer, loss='mae')

# %%
model.compile(optimizer="adam", loss='mae')

# %%
history = model.fit(X_train.values.astype(np.float32), y_train.values.astype(np.float32), epochs=180, batch_size=1024,
         validation_data=(X_eval.values.astype(np.float32), y_eval.values.astype(np.float32)), shuffle=True)
# Out:
# Epoch 1/180
# 312/312 [==============================] - 2s 5ms/step - loss: 15.5315 - val_loss: 14.7847
# Epoch 2/180
# 312/312 [==============================] - 1s 4ms/step - loss: 10.6894 - val_loss: 7.2179
# Epoch 3/180
# 312/312 [==============================] - 2s 5ms/step - loss: 7.2973 - val_loss: 7.1031
# Epoch 4/180
# 312/312 [==============================] - 2s 6ms/step - loss: 7.1270 - val_loss: 6.9223
# Epoch 5/180
# 312/312 [==============================] - 1s 4ms/step - loss: 7.0203 - val_loss: 6.8006
# Epoch 6/180
# 312/312 [==============================] - 2s 7ms/step - loss: 6.9413 - val_loss: 6.7786
# Epoch 7/180
# 312/312 [==============================] - 2s 6ms/step - loss: 6.9014 - val_loss: 6.8533
# Epoch 8/180
# 312/312 [==============================] - 3s 9ms/step - loss: 6.8621 - val_loss: 6.7263
# Epoch 9/180
# 312/312 [==============================] - 7s 22ms/step - loss: 6.8252 - val_loss: 6.6773
# Epoch 10/180
# 312/312 [==============================] - 3s 8ms/step - loss: 6.7946 - val_loss: 6.6675
# Epoch 11/180
# 312/312 [==============================] - 4s 12ms/step - loss: 6.7860 - val_loss: 6.6731
# Epoch 12/180
# 312/312 [==============================] - 3s 8ms/step - loss: 6.7582 - val_loss: 6.7054
# Epoch 13/180
# 312/312 [==============================] - 4s 13ms/step - loss: 6.7498 - val_loss: 6.6925
# Epoch 14/180
# 312/312 [==============================] - 5s 15ms/step - loss: 6.7197 - val_loss: 6.7672
# Epoch 15/180
# 312/312 [==============================] - 8s 25ms/step - loss: 6.7077 - val_loss: 6.5719
# Epoch 16/180
# 312/312 [==============================] - 7s 23ms/step - loss: 6.6802 - val_loss: 6.5367
# Epoch 17/180
# 312/312 [==============================] - 6s 19ms/step - loss: 6.6665 - val_loss: 6.6277
# Epoch 18/180
# 312/312 [==============================] - 4s 13ms/step - loss: 6.6545 - val_loss: 6.6215
# Epoch 19/180
# 312/312 [==============================] - 5s 15ms/step - loss: 6.6413 - val_loss: 6.5424
# Epoch 20/180
# 312/312 [==============================] - 6s 18ms/step - loss: 6.6322 - val_loss: 6.5028
# Epoch 21/180
# 312/312 [==============================] - 2s 7ms/step - loss: 6.6289 - val_loss: 6.4767
# Epoch 22/180
# 312/312 [==============================] - 2s 8ms/step - loss: 6.6033 - val_loss: 6.4658
# Epoch 23/180
# 312/312 [==============================] - 2s 6ms/step - loss: 6.5959 - val_loss: 6.4565
# Epoch 24/180
# 312/312 [==============================] - 2s 6ms/step - loss: 6.5930 - val_loss: 6.4739
# Epoch 25/180
# 312/312 [==============================] - 4s 13ms/step - loss: 6.5763 - val_loss: 6.4464
# Epoch 26/180
# 312/312 [==============================] - 6s 18ms/step - loss: 6.5640 - val_loss: 6.4944
# Epoch 27/180
# 312/312 [==============================] - 2s 6ms/step - loss: 6.5617 - val_loss: 6.4275
# Epoch 28/180
# 312/312 [==============================] - 2s 6ms/step - loss: 6.5484 - val_loss: 6.3967
# Epoch 29/180
# 312/312 [==============================] - 2s 7ms/step - loss: 6.5299 - val_loss: 6.3690
# Epoch 30/180
# 312/312 [==============================] - 5s 16ms/step - loss: 6.5303 - val_loss: 6.3840
# Epoch 31/180
# 312/312 [==============================] - 3s 11ms/step - loss: 6.5422 - val_loss: 6.4038
# Epoch 32/180
# 312/312 [==============================] - 2s 7ms/step - loss: 6.5082 - val_loss: 6.4279
# Epoch 33/180
# 312/312 [==============================] - 2s 5ms/step - loss: 6.5121 - val_loss: 6.3422
# Epoch 34/180
# 312/312 [==============================] - 2s 6ms/step - loss: 6.4981 - val_loss: 6.4008
# Epoch 35/180
# 312/312 [==============================] - 4s 12ms/step - loss: 6.4907 - val_loss: 6.4202
# Epoch 36/180
# 312/312 [==============================] - 3s 8ms/step - loss: 6.4939 - val_loss: 6.3740
# Epoch 37/180
# 312/312 [==============================] - 3s 10ms/step - loss: 6.4907 - val_loss: 6.2823
# Epoch 38/180
# 312/312 [==============================] - 2s 5ms/step - loss: 6.4750 - val_loss: 6.3359
# Epoch 39/180
# 312/312 [==============================] - 1s 4ms/step - loss: 6.4763 - val_loss: 6.3570
# Epoch 40/180
# 312/312 [==============================] - 4s 11ms/step - loss: 6.4666 - val_loss: 6.2759
# Epoch 41/180
# 312/312 [==============================] - 3s 10ms/step - loss: 6.4578 - val_loss: 6.2935
# Epoch 42/180
# 312/312 [==============================] - 3s 11ms/step - loss: 6.4536 - val_loss: 6.2629
# Epoch 43/180
# 312/312 [==============================] - 2s 8ms/step - loss: 6.4329 - val_loss: 6.3099
# Epoch 44/180
# 312/312 [==============================] - 1s 4ms/step - loss: 6.4451 - val_loss: 6.2629
# Epoch 45/180
# 312/312 [==============================] - 2s 7ms/step - loss: 6.4224 - val_loss: 6.2337
# Epoch 46/180
# 312/312 [==============================] - 2s 7ms/step - loss: 6.4281 - val_loss: 6.3964
# Epoch 47/180
# 312/312 [==============================] - 2s 6ms/step - loss: 6.4261 - val_loss: 6.2695
# Epoch 48/180
# 312/312 [==============================] - 1s 5ms/step - loss: 6.4079 - val_loss: 6.2062
# Epoch 49/180
# 312/312 [==============================] - 3s 9ms/step - loss: 6.4120 - val_loss: 6.3111
# Epoch 50/180
# 312/312 [==============================] - 3s 8ms/step - loss: 6.4018 - val_loss: 6.2780
# Epoch 51/180
# 312/312 [==============================] - 2s 6ms/step - loss: 6.3920 - val_loss: 6.1881
# Epoch 52/180
# 312/312 [==============================] - 1s 3ms/step - loss: 6.3867 - val_loss: 6.2522
# Epoch 53/180
# 312/312 [==============================] - 2s 6ms/step - loss: 6.3870 - val_loss: 6.1838
# Epoch 54/180
# 312/312 [==============================] - 2s 6ms/step - loss: 6.3833 - val_loss: 6.1609
# Epoch 55/180
# 312/312 [==============================] - 1s 3ms/step - loss: 6.3724 - val_loss: 6.2384
# Epoch 56/180
# 312/312 [==============================] - 1s 4ms/step - loss: 6.3700 - val_loss: 6.3662
# Epoch 57/180
# 312/312 [==============================] - 3s 11ms/step - loss: 6.3630 - val_loss: 6.1490
# Epoch 58/180
# 312/312 [==============================] - 6s 19ms/step - loss: 6.3527 - val_loss: 6.1400
# Epoch 59/180
# 312/312 [==============================] - 6s 20ms/step - loss: 6.3414 - val_loss: 6.2015
# Epoch 60/180
# 312/312 [==============================] - 4s 14ms/step - loss: 6.3430 - val_loss: 6.1976
# Epoch 61/180
# 312/312 [==============================] - 4s 13ms/step - loss: 6.3333 - val_loss: 6.2059
# Epoch 62/180
# 312/312 [==============================] - 2s 7ms/step - loss: 6.3207 - val_loss: 6.1557
# Epoch 63/180
# 312/312 [==============================] - 2s 8ms/step - loss: 6.3297 - val_loss: 6.1415
# Epoch 64/180
# 312/312 [==============================] - 3s 8ms/step - loss: 6.3185 - val_loss: 6.1443
# Epoch 65/180
# 312/312 [==============================] - 2s 7ms/step - loss: 6.3210 - val_loss: 6.1018
# Epoch 66/180
# 312/312 [==============================] - 1s 4ms/step - loss: 6.3109 - val_loss: 6.1366
# Epoch 67/180
# 312/312 [==============================] - 5s 16ms/step - loss: 6.3008 - val_loss: 6.1144
# Epoch 68/180
# 312/312 [==============================] - 3s 9ms/step - loss: 6.2912 - val_loss: 6.2248
# Epoch 69/180
# 312/312 [==============================] - 2s 6ms/step - loss: 6.2963 - val_loss: 6.0852
# Epoch 70/180
# 312/312 [==============================] - 2s 7ms/step - loss: 6.2917 - val_loss: 6.0836
# Epoch 71/180
# 312/312 [==============================] - 2s 5ms/step - loss: 6.2816 - val_loss: 6.1279
# Epoch 72/180
# 312/312 [==============================] - 5s 16ms/step - loss: 6.2854 - val_loss: 6.1493
# Epoch 73/180
# 312/312 [==============================] - 4s 12ms/step - loss: 6.2739 - val_loss: 6.1062
# Epoch 74/180
# 312/312 [==============================] - 1s 3ms/step - loss: 6.2703 - val_loss: 6.0892
# Epoch 75/180
# 312/312 [==============================] - 2s 5ms/step - loss: 6.2673 - val_loss: 6.0724
# Epoch 76/180
# 312/312 [==============================] - 1s 3ms/step - loss: 6.2626 - val_loss: 6.1705
# Epoch 77/180
# 312/312 [==============================] - 1s 3ms/step - loss: 6.2567 - val_loss: 6.1048
# Epoch 78/180
# 312/312 [==============================] - 1s 3ms/step - loss: 6.2587 - val_loss: 6.0778
# Epoch 79/180
# 312/312 [==============================] - 1s 3ms/step - loss: 6.2402 - val_loss: 6.0106
# Epoch 80/180
# 312/312 [==============================] - 2s 8ms/step - loss: 6.2348 - val_loss: 6.1231
# Epoch 81/180
# 312/312 [==============================] - 3s 9ms/step - loss: 6.2358 - val_loss: 6.0183
# Epoch 82/180
# 312/312 [==============================] - 3s 9ms/step - loss: 6.2318 - val_loss: 6.0103
# Epoch 83/180
# 312/312 [==============================] - 3s 8ms/step - loss: 6.2233 - val_loss: 5.9981
# Epoch 84/180
# 312/312 [==============================] - 4s 12ms/step - loss: 6.2287 - val_loss: 6.0695
# Epoch 85/180
# 312/312 [==============================] - 2s 6ms/step - loss: 6.2224 - val_loss: 6.0658
# Epoch 86/180
# 312/312 [==============================] - 2s 8ms/step - loss: 6.2197 - val_loss: 5.9951
# Epoch 87/180
# 312/312 [==============================] - 2s 5ms/step - loss: 6.2149 - val_loss: 5.9762
# Epoch 88/180
# 312/312 [==============================] - 2s 6ms/step - loss: 6.2005 - val_loss: 6.2180
# Epoch 89/180
# 312/312 [==============================] - 2s 8ms/step - loss: 6.2118 - val_loss: 6.0114
# Epoch 90/180
# 312/312 [==============================] - 1s 5ms/step - loss: 6.2011 - val_loss: 5.9435
# Epoch 91/180
# 312/312 [==============================] - 3s 11ms/step - loss: 6.1949 - val_loss: 5.9987
# Epoch 92/180
# 312/312 [==============================] - 1s 4ms/step - loss: 6.2000 - val_loss: 6.0194
# Epoch 93/180
# 312/312 [==============================] - 1s 4ms/step - loss: 6.2029 - val_loss: 5.9578
# Epoch 94/180
# 312/312 [==============================] - 2s 6ms/step - loss: 6.1863 - val_loss: 5.9731
# Epoch 95/180
# 312/312 [==============================] - 2s 7ms/step - loss: 6.1838 - val_loss: 5.9554
# Epoch 96/180
# 312/312 [==============================] - 2s 6ms/step - loss: 6.1873 - val_loss: 5.9522
# Epoch 97/180
# 312/312 [==============================] - 2s 6ms/step - loss: 6.1786 - val_loss: 5.9639
# Epoch 98/180
# 312/312 [==============================] - 2s 5ms/step - loss: 6.1787 - val_loss: 5.9633
# Epoch 99/180
# 312/312 [==============================] - 2s 7ms/step - loss: 6.1652 - val_loss: 5.9442
# Epoch 100/180
# 312/312 [==============================] - 5s 15ms/step - loss: 6.1738 - val_loss: 5.9723
# Epoch 101/180
# 312/312 [==============================] - 2s 8ms/step - loss: 6.1746 - val_loss: 6.0037
# Epoch 102/180
# 312/312 [==============================] - 4s 12ms/step - loss: 6.1583 - val_loss: 6.0356
# Epoch 103/180
# 312/312 [==============================] - 2s 7ms/step - loss: 6.1628 - val_loss: 6.0182
# Epoch 104/180
# 312/312 [==============================] - 3s 9ms/step - loss: 6.1668 - val_loss: 5.9596
# Epoch 105/180
# 312/312 [==============================] - 3s 11ms/step - loss: 6.1569 - val_loss: 5.9157
# Epoch 106/180
# 312/312 [==============================] - 1s 4ms/step - loss: 6.1409 - val_loss: 5.8953
# Epoch 107/180
# 312/312 [==============================] - 3s 10ms/step - loss: 6.1479 - val_loss: 5.9121
# Epoch 108/180
# 312/312 [==============================] - 2s 5ms/step - loss: 6.1526 - val_loss: 5.9092
# Epoch 109/180
# 312/312 [==============================] - 4s 12ms/step - loss: 6.1451 - val_loss: 5.8960
# Epoch 110/180
# 312/312 [==============================] - 2s 6ms/step - loss: 6.1396 - val_loss: 5.9273
# Epoch 111/180
# 312/312 [==============================] - 4s 12ms/step - loss: 6.1372 - val_loss: 5.9305
# Epoch 112/180
# 312/312 [==============================] - 2s 6ms/step - loss: 6.1337 - val_loss: 5.8874
# Epoch 113/180
# 312/312 [==============================] - 1s 4ms/step - loss: 6.1290 - val_loss: 5.9499
# Epoch 114/180
# 312/312 [==============================] - 2s 5ms/step - loss: 6.1302 - val_loss: 5.8892
# Epoch 115/180
# 312/312 [==============================] - 1s 4ms/step - loss: 6.1284 - val_loss: 5.9324
# Epoch 116/180
# 312/312 [==============================] - 1s 4ms/step - loss: 6.1263 - val_loss: 5.9286
# Epoch 117/180
# 312/312 [==============================] - 1s 4ms/step - loss: 6.1186 - val_loss: 5.8801
# Epoch 118/180
# 312/312 [==============================] - 1s 5ms/step - loss: 6.1076 - val_loss: 5.9803
# Epoch 119/180
# 312/312 [==============================] - 2s 7ms/step - loss: 6.1186 - val_loss: 5.8810
# Epoch 120/180
# 312/312 [==============================] - 1s 5ms/step - loss: 6.1127 - val_loss: 5.8863
# Epoch 121/180
# 312/312 [==============================] - 2s 5ms/step - loss: 6.1106 - val_loss: 5.8774
# Epoch 122/180
# 312/312 [==============================] - 2s 6ms/step - loss: 6.1078 - val_loss: 5.8804
# Epoch 123/180
# 312/312 [==============================] - 1s 3ms/step - loss: 6.1044 - val_loss: 5.8519
# Epoch 124/180
# 312/312 [==============================] - 1s 3ms/step - loss: 6.0965 - val_loss: 6.0253
# Epoch 125/180
# 312/312 [==============================] - 1s 3ms/step - loss: 6.1107 - val_loss: 5.9063
# Epoch 126/180
# 312/312 [==============================] - 1s 4ms/step - loss: 6.0905 - val_loss: 5.8717
# Epoch 127/180
# 312/312 [==============================] - 1s 3ms/step - loss: 6.0988 - val_loss: 5.9494
# Epoch 128/180
# 312/312 [==============================] - 1s 4ms/step - loss: 6.0830 - val_loss: 5.9032
# Epoch 129/180
# 312/312 [==============================] - 1s 4ms/step - loss: 6.0948 - val_loss: 5.8783
# Epoch 130/180
# 312/312 [==============================] - 1s 4ms/step - loss: 6.0897 - val_loss: 5.8606
# Epoch 131/180
# 312/312 [==============================] - 2s 6ms/step - loss: 6.0811 - val_loss: 5.8783
# Epoch 132/180
# 312/312 [==============================] - 3s 8ms/step - loss: 6.0843 - val_loss: 5.8735
# Epoch 133/180
# 312/312 [==============================] - 2s 6ms/step - loss: 6.0741 - val_loss: 5.8581
# Epoch 134/180
# 312/312 [==============================] - 2s 8ms/step - loss: 6.0726 - val_loss: 5.8607
# Epoch 135/180
# 312/312 [==============================] - 7s 24ms/step - loss: 6.0726 - val_loss: 5.8640
# Epoch 136/180
# 312/312 [==============================] - 8s 25ms/step - loss: 6.0770 - val_loss: 5.9719
# Epoch 137/180
# 312/312 [==============================] - 6s 20ms/step - loss: 6.0727 - val_loss: 5.8570
# Epoch 138/180
# 312/312 [==============================] - 6s 20ms/step - loss: 6.0627 - val_loss: 5.8881
# Epoch 139/180
# 312/312 [==============================] - 4s 11ms/step - loss: 6.0638 - val_loss: 5.8819
# Epoch 140/180
# 312/312 [==============================] - 3s 8ms/step - loss: 6.0606 - val_loss: 5.8902
# Epoch 141/180
# 312/312 [==============================] - 4s 12ms/step - loss: 6.0678 - val_loss: 5.8706
# Epoch 142/180
# 312/312 [==============================] - 3s 10ms/step - loss: 6.0590 - val_loss: 5.8403
# Epoch 143/180
# 312/312 [==============================] - 2s 5ms/step - loss: 6.0502 - val_loss: 5.9465
# Epoch 144/180
# 312/312 [==============================] - 3s 9ms/step - loss: 6.0615 - val_loss: 5.9014
# Epoch 145/180
# 312/312 [==============================] - 2s 7ms/step - loss: 6.0470 - val_loss: 6.0135
# Epoch 146/180
# 312/312 [==============================] - 1s 3ms/step - loss: 6.0619 - val_loss: 5.8450
# Epoch 147/180
# 312/312 [==============================] - 3s 9ms/step - loss: 6.0435 - val_loss: 5.8590
# Epoch 148/180
# 312/312 [==============================] - 2s 8ms/step - loss: 6.0517 - val_loss: 5.8448
# Epoch 149/180
# 312/312 [==============================] - 2s 5ms/step - loss: 6.0439 - val_loss: 5.8589
# Epoch 150/180
# 312/312 [==============================] - 1s 3ms/step - loss: 6.0440 - val_loss: 5.8948
# Epoch 151/180
# 312/312 [==============================] - 1s 4ms/step - loss: 6.0421 - val_loss: 5.8445
# Epoch 152/180
# 312/312 [==============================] - 1s 4ms/step - loss: 6.0280 - val_loss: 5.9243
# Epoch 153/180
# 312/312 [==============================] - 1s 3ms/step - loss: 6.0510 - val_loss: 5.8619
# Epoch 154/180
# 312/312 [==============================] - 1s 3ms/step - loss: 6.0382 - val_loss: 5.8449
# Epoch 155/180
# 312/312 [==============================] - 2s 7ms/step - loss: 6.0267 - val_loss: 5.8368
# Epoch 156/180
# 312/312 [==============================] - 2s 5ms/step - loss: 6.0275 - val_loss: 5.8861
# Epoch 157/180
# 312/312 [==============================] - 1s 3ms/step - loss: 6.0286 - val_loss: 5.8931
# Epoch 158/180
# 312/312 [==============================] - 1s 4ms/step - loss: 6.0231 - val_loss: 5.8606
# Epoch 159/180
# 312/312 [==============================] - 2s 7ms/step - loss: 6.0301 - val_loss: 5.8631
# Epoch 160/180
# 312/312 [==============================] - 2s 6ms/step - loss: 6.0298 - val_loss: 5.8747
# Epoch 161/180
# 312/312 [==============================] - 3s 9ms/step - loss: 6.0178 - val_loss: 5.8438
# Epoch 162/180
# 312/312 [==============================] - 3s 9ms/step - loss: 6.0217 - val_loss: 5.9000
# Epoch 163/180
# 312/312 [==============================] - 1s 3ms/step - loss: 6.0090 - val_loss: 5.8914
# Epoch 164/180
# 312/312 [==============================] - 1s 4ms/step - loss: 6.0105 - val_loss: 5.8250
# Epoch 165/180
# 312/312 [==============================] - 2s 7ms/step - loss: 6.0062 - val_loss: 5.8355
# Epoch 166/180
# 312/312 [==============================] - 3s 10ms/step - loss: 6.0172 - val_loss: 5.8932
# Epoch 167/180
# 312/312 [==============================] - 2s 7ms/step - loss: 6.0299 - val_loss: 5.8487
# Epoch 168/180
# 312/312 [==============================] - 1s 4ms/step - loss: 6.0143 - val_loss: 5.8489
# Epoch 169/180
# 312/312 [==============================] - 1s 3ms/step - loss: 6.0059 - val_loss: 5.8430
# Epoch 170/180
# 312/312 [==============================] - 1s 3ms/step - loss: 6.0042 - val_loss: 5.8412
# Epoch 171/180
# 312/312 [==============================] - 1s 3ms/step - loss: 5.9993 - val_loss: 5.9128
# Epoch 172/180
# 312/312 [==============================] - 1s 5ms/step - loss: 6.0014 - val_loss: 5.8601
# Epoch 173/180
# 312/312 [==============================] - 1s 4ms/step - loss: 5.9994 - val_loss: 5.8804
# Epoch 174/180
# 312/312 [==============================] - 5s 16ms/step - loss: 6.0016 - val_loss: 5.8532
# Epoch 175/180
# 312/312 [==============================] - 3s 10ms/step - loss: 5.9936 - val_loss: 5.8193
# Epoch 176/180
# 312/312 [==============================] - 2s 8ms/step - loss: 5.9883 - val_loss: 5.8343
# Epoch 177/180
# 312/312 [==============================] - 2s 5ms/step - loss: 5.9889 - val_loss: 5.8330
# Epoch 178/180
# 312/312 [==============================] - 2s 6ms/step - loss: 5.9789 - val_loss: 5.8995
# Epoch 179/180
# 312/312 [==============================] - 2s 7ms/step - loss: 5.9816 - val_loss: 5.8295
# Epoch 180/180
# 312/312 [==============================] - 2s 5ms/step - loss: 5.9859 - val_loss: 5.8407

# %%
plt.plot(history.epoch, history.history["loss"], 'b', label='Training loss')
plt.plot(history.epoch, history.history["val_loss"], 'g', label='Validation loss')
plt.title('Training loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
model.evaluate(X_eval.values.astype(np.float32),  y_eval.values.astype(np.float32), verbose=2)
# Out:
# 1107/1107 - 2s - loss: 5.8407 - 2s/epoch - 1ms/step
# 5.84072732925415

# %%
pred = model.predict(X_train.values.astype(np.float32))
print(pred)
# Out:
# 9956/9956 [==============================] - 11s 1ms/step
# [[-1.9103792e-03]
#  [ 1.1090050e+00]
#  [-2.3389664e-03]
#  ...
#  [ 1.1653619e+00]
#  [ 9.2823245e-04]
#  [ 1.3030624e+00]]

# %%
# plt.scatter(X_train["favorites_count"], model.predict(X_train))
# plt.scatter(X_train["favorites_count"], y_train.values.astype(np.float32))

# %%
# evaluation

eval_data = pd.read_csv("data/evaluation_with_embeddings.csv")
tweets = eval_data["TweetID"]

# %%
eval_data["url_count"] = eval_data["urls"].apply(lambda s: s[1:-1].count("\'")/2)
eval_data["text_len"] = eval_data["text"].apply(lambda s: len(s))
eval_data["hashtags_count"] = eval_data["hashtags"].apply(lambda s: s[1:-1].count("\'")/2)
eval_data["day"] = eval_data["timestamp"].apply(lambda t: datetime.utcfromtimestamp(t/1000).day)
eval_data["hour"] = eval_data["timestamp"].apply(lambda t: datetime.utcfromtimestamp(t/1000).hour)
eval_data["Macron"] =  eval_data["text"].apply(lambda s: ("macron" in s.lower().split()))
eval_data["Zemmour"] =  eval_data["text"].apply(lambda s: ("zemmour" in s.lower().split()))
eval_data["Melenchon"] =  eval_data["text"].apply(lambda s: ("melenchon" in s.lower().split()))
eval_data["rt"] =  eval_data["text"].apply(lambda s: ("rt" in s.lower().split()))

# print("sentiment analysis...")
# eval_data["compound"] =  eval_data["text"].apply(lambda s: sia.polarity_scores(s)['compound'])

eval_data = eval_data.drop(["text", "urls", "mentions", "hashtags", "timestamp", "TweetID"], axis=1)

# normalize
eval_data.loc[:, normal_columns] = (eval_data.loc[:, normal_columns] - mu) / sigma

print(eval_data)

pred = model.predict(eval_data.values.astype(np.float32))

print(pred)

# output normalization
for i,p in enumerate(pred):
    if p<0: pred[i] = 0
# Out:
#         Unnamed: 0  favorites_count  followers_count  statuses_count  \
# 0        -1.731691        -0.055089        -0.077561       -0.384487
# 1        -1.731681        -0.055089        -0.076250       -0.130940
# 2        -1.731672        -0.047990        -0.073569       -0.308274
# 3        -1.731662        -0.052722        -0.071378       -0.197070
# 4        -1.731652        -0.055089        -0.076932       -0.241396
# ...            ...              ...              ...             ...
# 117985   -0.577125        -0.055089        -0.077871       -0.421834
# 117986   -0.577115        -0.055089        -0.075036       -0.076371
# 117987   -0.577105        -0.040891        -0.074347       -0.403582
# 117988   -0.577095        -0.055089        -0.077867       -0.423504
# 117989   -0.577086        -0.055089        -0.075760       -0.373401
#
#         friends_count  verified         0         1         2         3  ...  \
# 0           -0.451430         0 -0.335875  0.285524 -0.536280 -0.147956  ...
# 1           -0.405207         0  0.810783  0.603325 -1.038255 -1.061037  ...
# 2            0.054226         0 -0.401258  0.376570 -0.629543 -0.903957  ...
# 3            0.229552         0 -2.321845 -3.908959  0.646365  1.752335  ...
# 4           -0.434694         0  1.737298 -0.033725  1.741830  0.807575  ...
# ...               ...       ...       ...       ...       ...       ...  ...
# 117985      -0.556227         0 -0.257144  0.319186 -0.255217 -0.406363  ...
# 117986      -0.225498         0 -0.880036  0.017175  0.422198 -0.474779  ...
# 117987      -0.518372         0 -0.594550  0.152154  0.497115 -0.512583  ...
# 117988      -0.549851         0 -0.015026  0.561627  0.463078  0.037825  ...
# 117989      -0.522357         0  0.630448  1.760061 -1.736072 -0.522344  ...
#
#               15  url_count  text_len  hashtags_count       day  hour  Macron  \
# 0       0.690603        0.0 -1.057548        2.208030  1.083457    12   False
# 1       0.503657        0.0 -0.913399       -0.384757  1.083457    11   False
# 2      -0.125263        0.0 -0.673151        0.911637 -1.332955     8   False
# 3      -0.884534        1.0  1.152732       -0.384757 -0.426800     8    True
# 4      -1.054622        2.0  1.489079       -0.384757  1.385508    21   False
# ...          ...        ...       ...             ...       ...   ...     ...
# 117985  0.141845        0.0 -1.009498       -0.384757 -0.728852    16   False
# 117986  0.646314        1.0  1.801401       -0.384757  0.781405     4   False
# 117987 -1.153626        0.0 -0.048507       -0.384757  0.781405    13    True
# 117988 -0.841490        1.0  1.585178       -0.384757  1.083457    12   False
# 117989  0.912071        0.0 -0.120581       -0.384757 -0.124749    13   False
#
#         Zemmour  Melenchon     rt
# 0         False      False  False
# 1         False      False  False
# 2         False      False  False
# 3         False      False  False
# 4          True      False  False
# ...         ...        ...    ...
# 117985    False      False  False
# 117986    False      False  False
# 117987    False      False  False
# 117988    False      False  False
# 117989    False      False   True
#
# [117990 rows x 31 columns]
# 3688/3688 [==============================] - 5s 1ms/step
# [[ 2.4540219e-03]
#  [ 3.0331099e-02]
#  [ 1.8931091e+00]
#  ...
#  [ 4.1049271e+00]
#  [-1.9016769e-03]
#  [ 1.5431890e-02]]

# %%
with open("data/predictions.csv", 'w') as f:
    writer = csv.writer(f)
    writer.writerow(["TweetID", "retweets_count"])
    for index, prediction in enumerate(pred):
        writer.writerow([str(tweets[index]) , str(int(prediction))])
